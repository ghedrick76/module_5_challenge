# %%
# This will allow you to select a ticker to run through the Alpacas API.

# Select 5 tickers to enter into your portfolio.  A database will be created that contains all of your tickers.

# %%
import os
import requests
import json
import pandas as pd
from dotenv import load_dotenv
import alpaca_trade_api as tradeapi
from MCForecastTools import MCSimulation

# %matplotlib inline

# %%
load_dotenv()
# Out:
# True

# %%
alpaca_api = os.getenv("ALPACA_API_KEY")
alpaca_secret = os.getenv("ALPACA_SECRET_KEY")
type(alpaca_api)
type(alpaca_secret)

# Create the Alpaca tradeapi.REST object
alpaca = tradeapi.REST(
    alpaca_api,
    alpaca_secret,
    api_version="v2"
)

# %%
# Set the tickers for both the bond and stock portion of the portfolio


# Set timeframe to 1Day
timeframe = "1Day"

# Format current date as ISO format
# Set both the start and end date at the date of your prior weekday 
# This will give you the closing price of the previous trading day
# Alternatively you can use a start and end date of 2020-08-07
start_date = pd.Timestamp("2020-04-21", tz="America/New_York").isoformat()
end_date = pd.Timestamp("2020-04-21", tz="America/New_York").isoformat()

# %%
tickers = []

tickers.append(input("Enter your first stock ticker (as it appears on the exchange (example: BBBY)) "))
tickers.append(input("Enter your second stock ticker."))
tickers.append(input("Enter your third stock ticker."))
tickers.append(input("Enter your fourth stock ticker."))
tickers.append(input("Enter your fifth stock ticker."))
print(f"The tickers you have selected are: {tickers}")
# Out:
# Enter your first stock ticker (as it appears on the exchange (example: BBBY))  SPY
# Enter your second stock ticker. GME
# Enter your third stock ticker. AMC
# Enter your fourth stock ticker. GOOG
# Enter your fifth stock ticker. AMZN
# The tickers you have selected are: ['SPY', 'GME', 'AMC', 'GOOG', 'AMZN']

# %%
#for ticker in tickers:

# %%
# Use the Alpaca get_bars function to get current closing prices the portfolio
# Be sure to set the `df` property after the function to format the response object as a DataFrame
stock_bond = alpaca.get_bars(
    tickers,
    timeframe,
    start = start_date,
    end = end_date
).df
    
# Reorganize the DataFrame
# Separate ticker data
ticker_1 = stock_bond[stock_bond['symbol']==stock_bond.iloc[:,7]].drop('symbol', axis=1)
ticker_2 = stock_bond[stock_bond['symbol']==stock_bond.iloc[:,7]].drop('symbol', axis=1)
ticker_3 = stock_bond[stock_bond['symbol']==stock_bond.iloc[:,7]].drop('symbol', axis=1)
ticker_4 = stock_bond[stock_bond['symbol']==stock_bond.iloc[:,7]].drop('symbol', axis=1)
ticker_5 = stock_bond[stock_bond['symbol']==stock_bond.iloc[:,7]].drop('symbol', axis=1)
# Concatenate the ticker DataFrames
stock_bond_df = pd.concat([ticker_1, ticker_2, ticker_3, ticker_4, ticker_5], axis=1, keys=[tickers[0], tickers[1], tickers[2], tickers[3], tickers[4]])

# Review the first 5 rows of the Alpaca DataFrame
stock_bond_df.head()
# Out:
#                                SPY                                          \
#                               open       high      low    close     volume
# timestamp
# 2020-04-21 04:00:00+00:00     3.20     3.3800     3.15     3.25    5788407
# 2020-04-21 04:00:00+00:00  2417.50  2428.3099  2279.66  2328.12    7476696
# 2020-04-21 04:00:00+00:00     5.23     5.3000     4.76     4.78    4142054
# 2020-04-21 04:00:00+00:00  1246.27  1254.2700  1209.71  1216.34    2153003
# 2020-04-21 04:00:00+00:00   276.48   278.0400   272.02   273.04  126387834
#
#                                                         GME             \
#                           trade_count         vwap     open       high
# timestamp
# 2020-04-21 04:00:00+00:00       25109     3.241996     3.20     3.3800
# 2020-04-21 04:00:00+00:00      272681  2343.749939  2417.50  2428.3099
# 2020-04-21 04:00:00+00:00       20092     4.977210     5.23     5.3000
# 2020-04-21 04:00:00+00:00       81297  1225.058231  1246.27  1254.2700
# 2020-04-21 04:00:00+00:00      923555   274.755324   276.48   278.0400
#
#                                     ...       GOOG                           \
#                                low  ...     volume trade_count         vwap
# timestamp                           ...
# 2020-04-21 04:00:00+00:00     3.15  ...    5788407       25109     3.241996
# 2020-04-21 04:00:00+00:00  2279.66  ...    7476696      272681  2343.749939
# 2020-04-21 04:00:00+00:00     4.76  ...    4142054       20092     4.977210
# 2020-04-21 04:00:00+00:00  1209.71  ...    2153003       81297  1225.058231
# 2020-04-21 04:00:00+00:00   272.02  ...  126387834      923555   274.755324
#
#                               AMZN                                          \
#                               open       high      low    close     volume
# timestamp
# 2020-04-21 04:00:00+00:00     3.20     3.3800     3.15     3.25    5788407
# 2020-04-21 04:00:00+00:00  2417.50  2428.3099  2279.66  2328.12    7476696
# 2020-04-21 04:00:00+00:00     5.23     5.3000     4.76     4.78    4142054
# 2020-04-21 04:00:00+00:00  1246.27  1254.2700  1209.71  1216.34    2153003
# 2020-04-21 04:00:00+00:00   276.48   278.0400   272.02   273.04  126387834
#
#
#                           trade_count         vwap
# timestamp
# 2020-04-21 04:00:00+00:00       25109     3.241996
# 2020-04-21 04:00:00+00:00      272681  2343.749939
# 2020-04-21 04:00:00+00:00       20092     4.977210
# 2020-04-21 04:00:00+00:00       81297  1225.058231
# 2020-04-21 04:00:00+00:00      923555   274.755324
#
# [5 rows x 35 columns]
